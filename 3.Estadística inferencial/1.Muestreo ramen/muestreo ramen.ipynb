# %%
import pandas as pd

# %%
df_ramen = pd.read_csv('ramen-ratings.csv')
df_ramen.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup     USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 4                                    Singapore Curry  Pack   India  3.75
#
#   Top Ten
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
df_ramen.shape
# Out:
# (2580, 7)

# %% [markdown]
# ## Muestreo con reposición

# %%
styles = df_ramen['Brand'].unique().tolist()
print(f'Existen {len(styles)} estilos de ramen en el dataset')
# Out:
# Existen 355 estilos de ramen en el dataset

# %%
df_ramen['Brand'].sample(n=20, replace=True).tolist()
# Out:
# ['Vifon',
#  'Mr. Udon',
#  'Vifon',
#  'Western Family',
#  'Pot Noodle',
#  'TTL',
#  'Maruchan',
#  'MAMA',
#  'Maruchan',
#  'Nongshim',
#  'Nagao Noodle',
#  'Unif / Tung-I',
#  'Nissin',
#  "Ching's Secret",
#  'A-Sha Dry Noodle',
#  'Maruchan',
#  'Unif',
#  'Koka',
#  'Sawadee',
#  'Nissin']

# %% [markdown]
# ### Realizaremos 500 extracciones con reposición de muestras de tamaño 100

# %%
muestras_estilos = []
for i in range(500):
    muestras_estilos.append(df_ramen['Brand'].sample(n=100, replace=True).tolist())

print(f'Cantidad de muestras: {len(muestras_estilos)}')
print(f'Tamaño de cada de muestras: {len(muestras_estilos[0])}')
print(f'Total de datos: {len(muestras_estilos) * len(muestras_estilos[0]):,}')
muestras_estilos
# Out:
# Cantidad de muestras: 500
# Tamaño de cada de muestras: 100
# Total de datos: 50,000
# [['Samyang Foods',
#   'Myojo',
#   'Fashion Foods',
#   'Nissin',
#   'MyKuali',
#   'Nissin',
#   'Mama',
#   'Mama',
#   'Nongshim',
#   'Samyang Foods',
#   'KOKA',
#   'Mama',
#   'Pot Noodle',
#   'MyOri',
#   'Deshome',
#   'Migawon',
#   'Ohsung',
#   'Four Seas',
#   'Happy Family',
#   'Mi Sedaap',
#   'ICA',
#   'Nissin',
#   'Ottogi',
#   'Mama',
#   'Nongshim',
#   'Mee Jang',
#   'Paldo',
#   'Samyang Foods',
#   'Bon Go Jang',
#   'Ogasawara',
#   'Myojo',
#   'Dream Kitchen',
#   'Wu Mu',
#   'SuperMi',
#   'ABC',
#   'Myojo',
#   'Tesco',
#   'Nissin',
#   'Maggi',
#   'Nissin',
#   'Yamamori',
#   'MyKuali',
#   'Maruchan',
#   'Just Way',
#   'Unif',
#   'Nissin',
#   'Paldo',
#   'Nissin',
#   'Knorr',
#   'Tokyo Noodle',
#   'Nissin',
#   'Nissin',
#   'Six Fortune',
#   'Myojo',
#   'MyKuali',
#   'Fashion Food',
#   'Ikeda Shoku',
#   'Kamfen',
#   'Maruchan',
# ...

# %% [markdown]
# ### Realizaremos 500 extracciones sin reposición de muestras de tamaño 100

# %%
muestras_estilos2 = []
for i in range(500):
    muestras_estilos2.append(df_ramen['Brand'].sample(n=100).tolist())

print(f'Cantidad de muestras: {len(muestras_estilos2)}')
print(f'Tamaño de cada de muestras: {len(muestras_estilos2[0])}')
print(f'Total de datos: {len(muestras_estilos2) * len(muestras_estilos2[0]):,}')
muestras_estilos2
# Out:
# Cantidad de muestras: 500
# Tamaño de cada de muestras: 100
# Total de datos: 50,000
# [['Nissin',
#   'Unif / Tung-I',
#   'Tesco',
#   'Nissin',
#   'Vifon',
#   'Nissin',
#   'Nissin',
#   'Myojo',
#   'Kiki Noodle',
#   'Takamori Kosan',
#   'Kamfen',
#   'Fuku',
#   'Dragonfly',
#   'Lucky Me!',
#   'Vina Acecook',
#   'Fujiwara',
#   'Indomie',
#   'Paldo',
#   'SuperMi',
#   'Maggi',
#   'Ogasawara',
#   'Nissin',
#   'Sapporo Ichiban',
#   'Paldo',
#   'ORee Garden',
#   'Sapporo Ichiban',
#   'Dragonfly',
#   'Myojo',
#   'Tokushima Seifun',
#   'Nissin',
#   'Nissin',
#   'Nongshim',
#   'Saigon Ve Wong',
#   'KOKA',
#   'Pot Noodle',
#   'Golden Wheat',
#   'Itsuki',
#   'Takamori Kosan',
#   'Sapporo Ichiban',
#   'Baijia',
#   'Foodmon',
#   'Nissin',
#   'Ottogi',
#   'Payless',
#   'Nissin',
#   'Mamee',
#   'Sichuan Baijia',
#   'Wei Lih',
#   'Vifon',
#   'Indomie',
#   'Nissin',
#   'Nongshim',
#   'Love Cook',
#   'Lucky Me!',
#   'Nissin',
#   'Fujiwara',
# ...
